# %%
from numerics.idling_experiment import IdlingExperiment
from main.compiling.NoiseModel import CodeCapactiyBitFlipNoise
import numpy as np
import matplotlib.pyplot as plt

# %%
def calculate_ler(per, distance):
    noise_model = CodeCapactiyBitFlipNoise(per)
    exp = IdlingExperiment('RotatedSurfaceCode', distance, noise_model)
    return(exp.calculate_ler(5000))

def calculate_ler_array(per_array, distance_array):
    ler_dict = dict()

    for d in distance_array:
        ler_dict[d] = dict()
        for per in per_array:
            ler_dict[d][per] = calculate_ler(per, d)
    return(ler_dict)

# %%
def plot_ler(ler_dict):
    for distance in ler_dict:
        per_array = []
        ler_array = []
        for per in ler_dict[distance]:
            ler_array.append(ler_dict[distance][per])
            per_array.append(per)
        plt.plot(per_array,ler_array, label = 'd =' + str(distance))
    plt.yscale("log")
    plt.legend()

# %%
ler_dict = calculate_ler_array(np.arange(0,0.2,0.01),np.arange(5,12,2))

# %%
plot_ler(ler_dict)
